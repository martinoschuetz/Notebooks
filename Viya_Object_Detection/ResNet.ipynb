# %% [markdown]
# # All the ResNet we have now

# %%
# %matplotlib inline
from swat import * # needed to start a CAS server.
sess = CAS('cas01.unx.sas.com', 14931, nworkers=2)

# %%
import sys
sys.path.append('\\\\sashq\\root\\dept\\cas\\leliuz\\DL_APIs')

# %%
from dl_api import Model, Sequential
from dl_api.layers import * 
from dl_api.applications import *
from dl_api.ResNet import *

# %% [markdown]
# **NOTE:**
# * If you want to build the excaly same structure in paper [a], please add batch_norm_first=False in the ResNetXX function.
# * The default is using the architacture in [b], with batch normalizaiton layer before the convoluation layer.
# * The model table will be save in the CAS table with name model.model_name
# * If you are not familiar with the model training procedure in this APIs, or do not feel confortable with it, please use DLtrain. Just use model = model.model_name in your options.
#
#
# **Refference**
# * [a] He, Kaiming, et al. "Deep residual learning for image recognition." Proceedings of the IEEE conference on computer vision and pattern recognition. 2016.
# * [b] He, Kaiming, et al. "Identity mappings in deep residual networks." European Conference on Computer Vision. Springer International Publishing, 2016.

# %% [markdown]
# ## ResNet18

# %%
model = ResNet18(sess,width=32, height=32,n_classes=10)
# Out:
# NOTE: Input layer added.
# NOTE: Convolutional layer added.
# NOTE: Batch Normalization layer added.
# NOTE: Pooling layer added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: Pooling layer added.
# NOTE: Output layer added.
# NOTE: Model compiled successfully.

# %%
ResNet18?

# %%
# This will be the CAStable name that saves the model
model.model_name
# Out:
# 'Model_7JGjDN'

# %%
model.summary()
# Out:
# *==================*===============*========*============*=================*======================*
# |   Layer (Type)   |  Kernel Size  | Stride | Activation |   Output Size   | Number of Parameters |
# *------------------*---------------*--------*------------*-----------------*----------------------*
# | Data(Input)      |     None      |  None  |    None    |   (32, 32, 3)   |        0 / 0         |
# | Conv1_1(Convo.)  |    (7, 7)     |   2    |  identity  |  (16, 16, 64)   |      9408 / 64       |
# | BN1_1(B.N.)      |     None      |  None  |    relu    |  (16, 16, 64)   |       128 / 0        |
# | Pool1(Pool)      |    (3, 3)     |   2    |    None    |   (8, 8, 64)    |        0 / 0         |
# | R2B1(B.N.)       |     None      |  None  |    relu    |   (8, 8, 64)    |       128 / 0        |
# | R2C1(Convo.)     |    (3, 3)     |   1    |  identity  |   (8, 8, 64)    |      36864 / 64      |
# ...

# %%
model.plot_network()

# %% [markdown]
# ## ResNet34

# %%
model = ResNet34(sess,n_classes=1000)
# Out:
# NOTE: Input layer added.
# NOTE: Convolutional layer added.
# NOTE: Batch Normalization layer added.
# NOTE: Pooling layer added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: Pooling layer added.
# NOTE: Output layer added.
# NOTE: Model compiled successfully.

# %%
model.summary()
# Out:
# *==================*===============*========*============*=================*======================*
# |   Layer (Type)   |  Kernel Size  | Stride | Activation |   Output Size   | Number of Parameters |
# *------------------*---------------*--------*------------*-----------------*----------------------*
# | Data(Input)      |     None      |  None  |    None    |  (224, 224, 3)  |        0 / 0         |
# | Conv1_1(Convo.)  |    (7, 7)     |   2    |  identity  | (112, 112, 64)  |      9408 / 64       |
# | BN1_1(B.N.)      |     None      |  None  |    relu    | (112, 112, 64)  |       128 / 0        |
# | Pool1(Pool)      |    (3, 3)     |   2    |    None    |  (56, 56, 64)   |        0 / 0         |
# | R2B1(B.N.)       |     None      |  None  |    relu    |  (56, 56, 64)   |       128 / 0        |
# | R2C1(Convo.)     |    (3, 3)     |   1    |  identity  |  (56, 56, 64)   |      36864 / 64      |
# ...

# %%
model.plot_network()

# %% [markdown]
# ## ResNet50

# %%
model = ResNet50(sess, n_classes = 1000)
# Out:
# NOTE: Input layer added.
# NOTE: Convolutional layer added.
# NOTE: Batch Normalization layer added.
# NOTE: Pooling layer added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: Pooling layer added.
# NOTE: Output layer added.
# NOTE: Model compiled successfully.

# %%
model.summary()
# Out:
# *==================*===============*========*============*=================*======================*
# |   Layer (Type)   |  Kernel Size  | Stride | Activation |   Output Size   | Number of Parameters |
# *------------------*---------------*--------*------------*-----------------*----------------------*
# | Data(Input)      |     None      |  None  |    None    |  (224, 224, 3)  |        0 / 0         |
# | Conv1_1(Convo.)  |    (7, 7)     |   2    |  identity  | (112, 112, 64)  |      9408 / 64       |
# | BN1_1(B.N.)      |     None      |  None  |    relu    | (112, 112, 64)  |       128 / 0        |
# | Pool1(Pool)      |    (3, 3)     |   2    |    None    |  (56, 56, 64)   |        0 / 0         |
# | R2B1(B.N.)       |     None      |  None  |    relu    |  (56, 56, 64)   |       128 / 0        |
# | R2C1(Convo.)     |    (1, 1)     |   1    |  identity  |  (56, 56, 64)   |      4096 / 64       |
# ...

# %%
model.model_info()
# Out:
# [ModelInfo]
#
#                                Descr                         Value
#  0                        Model Name                  model_06xsmo
#  1                        Model Type  Convolutional Neural Network
#  2                  Number of Layers                           118
#  3            Number of Input Layers                             1
#  4           Number of Output Layers                             1
#  5    Number of Convolutional Layers                            49
#  6          Number of Pooling Layers                             2
#  7  Number of Fully Connected Layers                             0
#  8  Number of Batch Normalization La                            49
#  9         Number of Residual Layers                            16
#
# + Elapsed: 0.0336s, user: 0.153s, sys: 0.041s, mem: 9.46mb

# %%
model.plot_network()

# %% [markdown]
# ## ResNet101

# %%
model = ResNet101(sess, n_classes = 1000)
# Out:
# NOTE: Input layer added.
# NOTE: Convolutional layer added.
# NOTE: Batch Normalization layer added.
# NOTE: Pooling layer added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# ...

# %%
model.summary()
# Out:
# *==================*===============*========*============*=================*======================*
# |   Layer (Type)   |  Kernel Size  | Stride | Activation |   Output Size   | Number of Parameters |
# *------------------*---------------*--------*------------*-----------------*----------------------*
# | Data(Input)      |     None      |  None  |    None    |  (224, 224, 3)  |        0 / 0         |
# | Conv1_1(Convo.)  |    (7, 7)     |   2    |  identity  | (112, 112, 64)  |      9408 / 64       |
# | BN1_1(B.N.)      |     None      |  None  |    relu    | (112, 112, 64)  |       128 / 0        |
# | Pool1(Pool)      |    (3, 3)     |   2    |    None    |  (56, 56, 64)   |        0 / 0         |
# | R2B1(B.N.)       |     None      |  None  |    relu    |  (56, 56, 64)   |       128 / 0        |
# | R2C1(Convo.)     |    (1, 1)     |   1    |  identity  |  (56, 56, 64)   |      4096 / 64       |
# ...

# %%
model.plot_network()

# %% [markdown]
# ## ResNet152

# %%
model = ResNet152(sess, n_classes = 1000)
# Out:
# NOTE: Input layer added.
# NOTE: Convolutional layer added.
# NOTE: Batch Normalization layer added.
# NOTE: Pooling layer added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# NOTE: A block of layers added.
# ...

# %%
model.summary()
# Out:
# *==================*===============*========*============*=================*======================*
# |   Layer (Type)   |  Kernel Size  | Stride | Activation |   Output Size   | Number of Parameters |
# *------------------*---------------*--------*------------*-----------------*----------------------*
# | Data(Input)      |     None      |  None  |    None    |  (224, 224, 3)  |        0 / 0         |
# | Conv1_1(Convo.)  |    (7, 7)     |   2    |  identity  | (112, 112, 64)  |      9408 / 64       |
# | BN1_1(B.N.)      |     None      |  None  |    relu    | (112, 112, 64)  |       128 / 0        |
# | Pool1(Pool)      |    (3, 3)     |   2    |    None    |  (56, 56, 64)   |        0 / 0         |
# | R2B1(B.N.)       |     None      |  None  |    relu    |  (56, 56, 64)   |       128 / 0        |
# | R2C1(Convo.)     |    (1, 1)     |   1    |  identity  |  (56, 56, 64)   |      4096 / 64       |
# ...

# %%
model.plot_network()
