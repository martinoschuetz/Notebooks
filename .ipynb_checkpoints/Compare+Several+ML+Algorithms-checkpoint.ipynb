# %% [markdown]
# This example illustrates fitting and comparing several Machine Learning algorithms for classifying the binary target in the
# big_organics data set.
#
# The steps include:
#
# 1. PREPARE AND EXPLORE
#   a) Check data is loaded into CAS
# <br>
# 2. PERFORM SUPERVISED LEARNING
#   a) Fit a model using a Random Forest
#   b) Fit a model using Gradient Boosting
#   c) Fit a model using a Neural Network
#   d) Fit a model using a Support Vector Machine
# <br>
# 3. EVALUATE AND IMPLEMENT
#   a) Score the data
#   b) Assess model performance
#   c) Generate ROC and Lift charts

# %% [markdown]
# ### Import packages

# %%
from swat import *
from pprint import pprint
from matplotlib import pyplot as plt
import pandas as pd
from swat.render import render_html
# %matplotlib inline
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ### CAS Server connection details

# %%
cashost='localhost'
casport=5570
casauth='~/.authinfo'
indata_dir="C:/Users/germsz/OneDrive - SAS/Data/DemoData"
#indata_dir="/home/sasdemo/data"
indata="big_organics"

# %% [markdown]
# ### Start CAS session

# %%
#sess = CAS(cashost, casport, authinfo="~/.authinfo", caslib="casuser")
sess = CAS('localhost', 5570, username="johndoe", password="SASpw1")
sess
# Out:
# CAS('localhost', 5570, 'johndoe', protocol='cas', name='py-session-1', session='ce967042-da01-fa4a-987b-a00d60fd71b4')

# %% [markdown]
# ### Import action sets

# %%
sess.loadactionset(actionset="dataStep")
sess.loadactionset(actionset="dataPreprocess")
sess.loadactionset(actionset="cardinality")
sess.loadactionset(actionset="sampling")
sess.loadactionset(actionset="regression")
sess.loadactionset(actionset="decisionTree")
sess.loadactionset(actionset="neuralNet")
sess.loadactionset(actionset="svm")
sess.loadactionset(actionset="astore")
sess.loadactionset(actionset="percentile")
# Out:
# NOTE: Added action set 'dataStep'.
# [actionset]
#
#  'dataStep'
#
# + Elapsed: 0.000344s, mem: 0.194mb
# NOTE: Added action set 'dataPreprocess'.
# [actionset]
#
#  'dataPreprocess'
#
# + Elapsed: 0.000661s, mem: 0.194mb
# NOTE: Added action set 'cardinality'.
# [actionset]
#
#  'cardinality'
#
# + Elapsed: 0.000644s, mem: 0.195mb
# NOTE: Added action set 'sampling'.
# [actionset]
#
#  'sampling'
#
# + Elapsed: 0.00163s, user: 0.01s, mem: 0.199mb
# NOTE: Added action set 'regression'.
# [actionset]
#
#  'regression'
#
# + Elapsed: 0.00175s, mem: 0.215mb
# NOTE: Added action set 'decisionTree'.
# [actionset]
#
#  'decisionTree'
#
# + Elapsed: 0.00118s, user: 0.01s, mem: 0.195mb
# NOTE: Added action set 'neuralNet'.
# [actionset]
#
#  'neuralNet'
#
# + Elapsed: 0.00128s, sys: 0.01s, mem: 0.224mb
# NOTE: Added action set 'svm'.
# [actionset]
#
#  'svm'
#
# + Elapsed: 0.00119s, mem: 0.202mb
# NOTE: Added action set 'astore'.
# [actionset]
#
#  'astore'
#
# + Elapsed: 0.00094s, mem: 0.195mb
# NOTE: Added action set 'percentile'.
# [actionset]
#
#  'percentile'
#
# + Elapsed: 0.000333s, mem: 0.194mb

# %% [markdown]
# ### Set variables for input data

# %%
target          = "targetbuy"
class_inputs    = ["DEmCluster", "PromClass", "DeMClusterGroup", "DemGender", "DemReg", "DemTvReg"]
class_vars      = [target] + class_inputs
interval_inputs = ["DeMAffl", "DemAge", "PromSpend", "PromTime"]
all_inputs      = interval_inputs + class_inputs
all_inputs
# Out:
# ['DeMAffl',
#  'DemAge',
#  'PromSpend',
#  'PromTime',
#  'DEmCluster',
#  'PromClass',
#  'DeMClusterGroup',
#  'DemGender',
#  'DemReg',
#  'DemTvReg']

# %% [markdown]
# ### Load data into CAS if needed

# %%
if not sess.table.tableExists(table=indata).exists:
    tbl = sess.upload_file(indata_dir+"/"+indata+".sas7bdat", casout={"name":indata})
# Out:
# NOTE: Cloud Analytic Services made the uploaded file available as table BIG_ORGANICS in caslib CASUSER(johndoe).
# NOTE: The table BIG_ORGANICS has been created in caslib CASUSER(johndoe) from binary data uploaded to Cloud Analytic Services.

# %% [markdown]
# ### Explore and Impute missing values

# %% [markdown]
# #### View first 5 observations from the data set

# %%
sess.fetch(table='big_organics', to=5)
# Out:
# [Fetch]
#
#  Ausgewählte Zeilen aus Tabelle BIG_ORGANICS
#
#              id  DemAffl  DemAge DemCluster DemClusterGroup DemGender  \
#  0  A0000000140     10.0    76.0         16               C         U
#  1  A0000000620      4.0    49.0         35               D         U
#  2  A0000000868      5.0    70.0         27               D         F
#  3  A0000001120     10.0    65.0         51               F         M
#  4  A0000002313     11.0    68.0         04               A         F
#
#       DemReg      DemTVReg PromClass  PromSpend  PromTime  TargetBuy  \
#  0  Midlands  Wales & West      Gold   16000.00       4.0        0.0
#  1  Midlands  Wales & West      Gold    6000.00       5.0        0.0
#  2  Midlands  Wales & West    Silver       0.02       8.0        1.0
#  3  Midlands      Midlands       Tin       0.01       7.0        1.0
#  4  Midlands      Midlands       Tin       0.01       8.0        0.0
#
#     TargetAmt  part
#  0        0.0   1.0
#  1        0.0   0.0
#  2        1.0   1.0
#  3        1.0   0.0
#  4        0.0   0.0
#
# + Elapsed: 0.00115s, mem: 0.879mb

# %% [markdown]
# #### Explore data and plot missing values

# %%
sess.cardinality.summarize(
  table={"name":indata}, 
  cardinality={"name":"data_card", "replace":True}
)

tbl_data_card=sess.CASTable('data_card')
tbl_data_card.where='_NMISS_>0'
print("Data Summary".center(80, '-')) # print title
tbl_data_card.fetch() # print obs

tbl_data_card

tbl_data_card.vars=['_VARNAME_', '_NMISS_', '_NOBS_']
allRows=20000  # Assuming max rows in data_card table is <= 20,000
df_data_card=tbl_data_card.fetch(to=allRows)['Fetch']
df_data_card['PERCENT_MISSING']=(df_data_card['_NMISS_']/df_data_card['_NOBS_'])*100

tbl_forplot=pd.Series(list(df_data_card['PERCENT_MISSING']), index=list(df_data_card['_VARNAME_']))
ax=tbl_forplot.plot(
  kind='bar', 
  title='Percentage of Missing Values'
)
ax.set_ylabel('Percent Missing')
ax.set_xlabel('Variable Names')
# Out:
# NOTE: Writing cardinality.
# NOTE: status = 0.
# NOTE: The Cloud Analytic Services server processed the request in 0,134322 seconds.
# + Elapsed: 0.135s, user: 0.56s, mem: 2.12mb
# ----------------------------------Data Summary----------------------------------
# [Fetch]
#
#  Ausgewählte Zeilen aus Tabelle DATA_CARD
#
#           _VARNAME_  _FMTWIDTH_ _TYPE_  _RLEVEL_ _ORDER_ _MORE_  _CARDINALITY_  \
#  0          DemAffl        12.0      N  INTERVAL     ASC      Y           30.0
#  1           DemAge        12.0      N  INTERVAL     ASC      Y           30.0
#  2       DemCluster         2.0      C        ID     ASC      Y           30.0
#  3  DemClusterGroup         1.0      C     CLASS     ASC      N            7.0
#  4        DemGender         1.0      C     CLASS     ASC      N            3.0
#  5           DemReg        10.0      C     CLASS     ASC      N            5.0
#  6         DemTVReg        12.0      C     CLASS     ASC      N           13.0
#  7         PromTime        12.0      N  INTERVAL     ASC      Y           30.0
#
#       _NOBS_  _SUMFREQS_  _NMISS_  ... _SKEWNESS_  _KURTOSIS_  _MFREQ_  \
#  0  111115.0    105690.0   5425.0  ...   0.891633    2.096236  13170.0
#  1  111115.0    103575.0   7540.0  ...  -0.079826   -0.843962  68930.0
#  2  111115.0    107745.0   3370.0  ...        NaN         NaN  44545.0
#  3  111115.0    107745.0   3370.0  ...        NaN         NaN  22830.0
#  4  111115.0     98555.0  12560.0  ...        NaN         NaN  60745.0
#  5  111115.0    108790.0   2325.0  ...        NaN         NaN  43170.0
#  6  111115.0    108790.0   2325.0  ...        NaN         NaN  30945.0
#  7  111115.0    109710.0   1405.0  ...   2.282665    8.075931  21570.0
#
#     _MFREQFOUNDLEVEL_  _MFREQNUM_  _MFREQCHR_   _MFREQCFMT_  _LASTNUM_  \
#  0                  Y         8.0                         8       29.0
#  1                  N         NaN                                 47.0
#  2                  N         NaN                                  NaN
#  3                  Y         NaN           C             C        NaN
#  4                  Y         NaN           F             F        NaN
#  5                  Y         NaN  South East    South East        NaN
#  6                  Y         NaN      London        London        NaN
#  7                  Y         5.0                         5       29.0
#
#      _LASTCHR_    _LASTCFMT_
#  0                        29
#  1                        47
#  2          30            30
#  3           U             U
#  4           U             U
#  5  South West    South West
#  6   Yorkshire     Yorkshire
#  7                        29
#
#  [8 rows x 26 columns]
#
# + Elapsed: 0.00189s, mem: 1.16mb
# CASTable('data_card', where='_NMISS_>0')
# Text(0, 0.5, 'Percent Missing')
# Text(0.5, 0, 'Variable Names')

# %% [markdown]
# #### Impute missing values

# %%
sess.dataPreprocess.transform(
  table={"name":indata},
  casOut={"name":"big_organics_prepped", "replace":True},
  copyAllVars=True,
  outVarsNameGlobalPrefix="IM",
  requestPackages=[
    {"impute":{"method":"MEAN"}, "inputs":{"DeMAffl", "DemAge", "PromSpend", "PromTime"}},
    {"impute":{"method":"MODE"},"inputs":{"DEmCluster", "PromClass", "DeMClusterGroup", "DemGender", "DemReg", "DemTvReg"}}
  ]
)
# Out:
# [TransInfo]
#
#  Transformationsanfragen für BIG_ORGANICS
#
#    ActualName  NTransVars ImputeMethod
#  0       _TR1           4         Mean
#  1       _TR2           6         Mode
#
# [VarTransInfo]
#
#  Informationen zu Variablentransformation für BIG_ORGANICS
#
#            Variable Transformation           ResultVar       N  NMiss  \
#  0          DemAffl             IM          IM_DemAffl  105690   5425
#  1           DemAge             IM           IM_DemAge  103575   7540
#  2        PromSpend             IM        IM_PromSpend  111115      0
#  3         PromTime             IM         IM_PromTime  109710   1405
#  4       DemCluster             IM       IM_DemCluster  107745   3370
#  5  DemClusterGroup             IM  IM_DemClusterGroup  107745   3370
#  6        DemGender             IM        IM_DemGender   98555  12560
#  7           DemReg             IM           IM_DemReg  108790   2325
#  8         DemTVReg             IM         IM_DemTVReg  108790   2325
#  9        PromClass             IM        IM_PromClass  111115      0
#
#     ImputedValueContinuous ImputedValueNominal
#  0                8.711893
#  1               53.797152
#  2             4420.590041
#  3                6.564670
#  4                     NaN                  52
#  5                     NaN                   C
#  6                     NaN                   F
#  7                     NaN          South East
#  8                     NaN              London
#  9                     NaN              Silver
#
# [NomVarInfo]
#
#  Informationen zu Nominalvariablen für BIG_ORGANICS
#
#            Variable         N    NMiss  NLevels
#  0       DemCluster  107745.0   3370.0     55.0
#  1  DemClusterGroup  107745.0   3370.0      7.0
#  2        DemGender   98555.0  12560.0      3.0
#  3           DemReg  108790.0   2325.0      5.0
#  4         DemTVReg  108790.0   2325.0     13.0
#  5        PromClass  111115.0      0.0      4.0
#
# [OutputCasTables]
#
#               casLib                  Name    Rows  Columns  \
#  0  CASUSER(johndoe)  big_organics_prepped  111115       24
#
#                                              casTable
#  0  CASTable('big_organics_prepped', caslib='CASUS...
#
# + Elapsed: 0.137s, user: 0.53s, sys: 0.01s, mem: 26.2mb

# %% [markdown]
# ### Partition data into Training and Validation

# %%
sess.sampling.stratified(
  table={"name":"big_organics_prepped", "groupBy":"targetbuy"},
  output={"casOut":{"name":"big_organics_part", "replace":True}, "copyVars":"ALL"},
  samppct=70,
  partind=True
)
# Out:
# NOTE: Using SEED=857875415 for sampling.
# [outputSize]
#
#  {'outputNObs': 111115.0, 'outputNVars': 25}
#
# [STRAFreq]
#
#  Häufigkeiten
#
#     ByGrpID     TargetBuy   NObs  NSamp
#  0        0             0  83590  58513
#  1        1             1  27525  19268
#
# [OutputCasTables]
#
#               casLib               Name Label    Rows  Columns  \
#  0  CASUSER(johndoe)  big_organics_part        111115       25
#
#                                              casTable
#  0  CASTable('big_organics_part', caslib='CASUSER(...
#
# + Elapsed: 0.071s, user: 0.25s, sys: 0.02s, mem: 26.8mb

# %% [markdown]
# ### Random Forest

# %%
rf = sess.decisionTree.forestTrain(
  table={
    "name":"big_organics_part",
    "where":"strip(put(_partind_, best.))='1'"
  },
  inputs=all_inputs,
  nominals=class_vars,
  target="targetbuy",
  nTree=50,
  nBins=20,
  leafSize=5,
  maxLevel=21,
  crit="GAINRATIO",
  varImp=True,
  missing="USEINSEARCH",
  vote="PROB",
  OOB=True,
  casOut={"name":"forest_model", "replace":True}
)

# Output model statistics
render_html(rf)

# Score 
sess.decisionTree.forestScore(
  table={"name":"big_organics_part"},
  modelTable={"name":"forest_model"},
  casOut={"name":"_scored_rf", "replace":True},
  copyVars={"targetbuy", "_partind_"},
  vote="PROB"
)

# Create p_targetbuy0 and p_targetbuy1 as _rf_predp_ is the probability of event in _rf_predname_
sess.dataStep.runCode(
  code="""data _scored_rf; set _scored_rf; if _rf_predname_=1 then do; p_targetbuy1=_rf_predp_; 
    p_targetbuy0=1-p_targetbuy1; end; if _rf_predname_=0 then do; p_targetbuy0=_rf_predp_; p_targetbuy1=1-p_targetbuy0; end; run;"""
)
# Out:
#     <style type="text/css">
#     div.cas-results {
#         overflow-x: auto;
#     }
#     div.cas-results > * {
#         margin-left: auto !important;
#         margin-right: auto !important;
#     }
#     div.cas-results .sas-dataframe th[colspan],
#     div.cas-results .byline {
#         text-align: center;
#         font-size: 110%;
#     }
#     div.cas-results .sas-dataframe > tbody > tr:nth-child(even) {
#         background-color: #f8f8f8;
#     }
#     div.cas-results .sas-dataframe td,
#     div.cas-results .sas-dataframe th {
#         border: 1px solid #aaaaaa;
#         padding: 5px 10px;
#     }
#     div.cas-results .sas-dataframe th {
#         background-color: #f0f0f0;
#     }
#     div.cas-results .sas-dataframe .double,
#     div.cas-results .sas-dataframe .int32,
#     div.cas-results .sas-dataframe .int64,
#     div.cas-results .sas-dataframe .decsext,
#     div.cas-results .sas-dataframe .decquad {
#         text-align: right;
#     }
#     </style>
# <div class="cas-results"><table class="sas-dataframe">
# <colgroup><col class="char" /><col class="double" /></colgroup>
# <thead>
# <tr><th colspan="2">Forest für BIG_ORGANICS_PART</th></tr>
# <th class="char">Descr</th>
# <th class="double">Value</th>
# </thead>
# <tbody>
# <tr><td class="char">Anzahl Bäume</td><td class="double">50</td></tr>
# <tr><td class="char">Anzahl der ausgewählten Variablen (M)</td><td class="double">4</td></tr>
# <tr><td class="char">Zufallszahl Seed</td><td class="double">0</td></tr>
# <tr><td class="char">Bootstrap Prozentwert (%)</td><td class="double">63.212055882</td></tr>
# <tr><td class="char">Anzahl der Intervalle</td><td class="double">20</td></tr>
# <tr><td class="char">Anzahl Variablen</td><td class="double">10</td></tr>
# <tr><td class="char">Konfidenzniveau für Pruning</td><td class="double">0.25</td></tr>
# <tr><td class="char">Max Anzahl der Baumknoten</td><td class="double">1769</td></tr>
# <tr><td class="char">Min Anzahl der Baumknoten</td><td class="double">785</td></tr>
# <tr><td class="char">Max Anzahl der Verzweigungen</td><td class="double">2</td></tr>
# <tr><td class="char">Min Anzahl der Verzweigungen</td><td class="double">2</td></tr>
# <tr><td class="char">Max Anzahl der Ebenen</td><td class="double">21</td></tr>
# <tr><td class="char">Min Anzahl der Ebenen</td><td class="double">21</td></tr>
# <tr><td class="char">Max Anzahl der Blätter</td><td class="double">885</td></tr>
# <tr><td class="char">Min Anzahl der Blätter</td><td class="double">393</td></tr>
# <tr><td class="char">Maximum Größe der Blätter</td><td class="double">13890</td></tr>
# <tr><td class="char">Minimum Größe der Blätter</td><td class="double">5</td></tr>
# <tr><td class="char">Out-of-Bag MCR (%)</td><td class="double">15.334079017</td></tr>
# </tbody>
# </table><table class="sas-dataframe">
# <colgroup><col class="double" /><col class="double" /><col class="double" /><col class="double" /><col class="double" /><col class="double" /><col class="double" /><col class="double"
# <tr><td class="double">13</td><td class="double">14</td><td class="double">8176</td><td class="double">0.1560487033</td><td class="double">0.3683242875</td><td class="double">0.1146015368</td><td class="double">0.3385284874</td><td class="double">1</td></tr>
# <tr><td class="double">14</td><td class="double">15</td><td class="double">8765</td><td class="double">0.155993263</td><td class="double">0.3679190619</td><td class="double">0.1144342773</td><td class="double">0.3382813581</td><td class="double">1</td></tr>
# <tr><td class="double">15</td><td class="double">16</td><td class="double">9185</td><td class="double">0.1561435312</td><td class="double">0.3684772733</td><td class="double">0.1146246282</td><td class="double">0.3385625913</td><td class="double">1</td></tr>
# <tr><td class="double">16</td><td class="double">17</td><td class="double">9724</td><td class="double">0.1559635387</td><td class="double">0.3686405097</td><td class="double">0.114644558</td><td class="double">0.338592023</td><td class="double">1</td></tr>
# <tr><td class="double">17</td><td class="double">18</td><td class="double">10316</td><td class="double">0.1557064064</td><td class="double">0.3685429063</td><td class="double">0.1145582957</td><td class="double">0.3384646151</td><td class="double">1</td></tr>
# <tr><td class="double">18</td><td class="double">19</td><td class="double">10826</td><td class="d
# [OutputCasTables]
#
#               casLib        Name    Rows  Columns  \
#  0  CASUSER(johndoe)  _scored_rf  111115        7
#
#                                              casTable
#  0  CASTable('_scored_rf', caslib='CASUSER(johndoe)')
#
# [ScoreInfo]
#
#                                Descr                             Value
#  0  Anzahl eingelesene Beobachtungen                            111115
#  1   Anzahl verwendete Beobachtungen                            111115
#  2    Fehlklassifizierungsfehler (%)                      14,804481843
#
# + Elapsed: 3.46s, user: 16.5s, sys: 0.22s, mem: 371mb
# NOTE: Character values have been converted to numeric values at the places given by: (Line):(Column).
#       0:35    0:127
# NOTE: Duplicate messages output by DATA step:
# NOTE: Character values have been converted to numeric values at the places given by: (Line):(Column).  (occurred 6 times)
#       0:35    0:127  (occurred 6 times)
# [InputCasTables]
#
#               casLib        Name    Rows  Columns  \
#  0  CASUSER(johndoe)  _scored_rf  111115        7
#
#                                              casTable
#  0  CASTable('_scored_rf', caslib='CASUSER(johndoe)')
#
# [OutputCasTables]
#
#               casLib        Name    Rows  Columns  Append  \
#  0  CASUSER(johndoe)  _scored_rf  111115        9     NaN
#
#                                              casTable
#  0  CASTable('_scored_rf', caslib='CASUSER(johndoe)')
#
# + Elapsed: 0.0353s, user: 0.08s, sys: 0.02s, mem: 6.5mb

# %% [markdown]
# ### Gradient Boosting

# %%
gb = sess.decisionTree.gbtreeTrain(
  table={
    "name":"big_organics_part",
    "where":"strip(put(_partind_, best.))='1'"
  },
  inputs=all_inputs,
  nominals=class_vars,
  target="targetbuy",
  nTree=10,
  nBins=20,
  maxLevel=6,
  varImp=True,
  missing="USEINSEARCH",
  casOut={"name":"gb_model", "replace":True}
)

# Output model statistics
render_html(gb)

# Score 
sess.decisionTree.gbtreeScore(
  table={"name":"big_organics_part"},
  modelTable={"name":"gb_model"},
  casOut={"name":"_scored_gb", "replace":True},
  copyVars={"targetbuy", "_partind_"}
)

# Create p_targetbuy0 and p_targetbuy1 as _gbt_predp_ is the probability of event in _gbt_predname_
sess.dataStep.runCode(
  code="""data _scored_gb; set _scored_gb; if _gbt_predname_=1 then do; p_targetbuy1=_gbt_predp_; 
    p_targetbuy0=1-p_targetbuy1; end; if _gbt_predname_=0 then do; p_targetbuy0=_gbt_predp_; p_targetbuy1=1-p_targetbuy0; end; run;"""
)
# Out:
#     <style type="text/css">
#     div.cas-results {
#         overflow-x: auto;
#     }
#     div.cas-results > * {
#         margin-left: auto !important;
#         margin-right: auto !important;
#     }
#     div.cas-results .sas-dataframe th[colspan],
#     div.cas-results .byline {
#         text-align: center;
#         font-size: 110%;
#     }
#     div.cas-results .sas-dataframe > tbody > tr:nth-child(even) {
#         background-color: #f8f8f8;
#     }
#     div.cas-results .sas-dataframe td,
#     div.cas-results .sas-dataframe th {
#         border: 1px solid #aaaaaa;
#         padding: 5px 10px;
#     }
#     div.cas-results .sas-dataframe th {
#         background-color: #f0f0f0;
#     }
#     div.cas-results .sas-dataframe .double,
#     div.cas-results .sas-dataframe .int32,
#     div.cas-results .sas-dataframe .int64,
#     div.cas-results .sas-dataframe .decsext,
#     div.cas-results .sas-dataframe .decquad {
#         text-align: right;
#     }
#     </style>
# <div class="cas-results"><table class="sas-dataframe">
# <colgroup><col class="char" /><col class="double" /></colgroup>
# <thead>
# <tr><th colspan="2">Gradient Boosting Tree für BIG_ORGANICS_PART</th></tr>
# <th class="char">Descr</th>
# <th class="double">Value</th>
# </thead>
# <tbody>
# <tr><td class="char">Anzahl Bäume</td><td class="double">10</td></tr>
# <tr><td class="char">Verteilung</td><td class="double">2</td></tr>
# <tr><td class="char">Lernrate</td><td class="double">0.1</td></tr>
# <tr><td class="char">Subsampling-Rate</td><td class="double">0.5</td></tr>
# <tr><td class="char">Anzahl der ausgewählten Variablen (M)</td><td class="double">10</td></tr>
# <tr><td class="char">Anzahl der Intervalle</td><td class="double">20</td></tr>
# <tr><td class="char">Anzahl Variablen</td><td class="double">10</td></tr>
# <tr><td class="char">Max Anzahl der Baumknoten</td><td class="double">63</td></tr>
# <tr><td class="char">Min Anzahl der Baumknoten</td><td class="double">61</td></tr>
# <tr><td class="char">Max Anzahl der Verzweigungen</td><td class="double">2</td></tr>
# <tr><td class="char">Min Anzahl der Verzweigungen</td><td class="double">2</td></tr>
# <tr><td class="char">Max Anzahl der Ebenen</td><td class="double">6</td></tr>
# <tr><td class="char">Min Anzahl der Ebenen</td><td class="double">6</td></tr>
# <tr><td class="char">Max Anzahl der Blätter</td><td class="double">32</td></tr>
# <tr><td class="char">Min Anzahl der Blätter</td><td class="double">31</td></tr>
# <tr><td class="char">Maximum Größe der Blätter</td><td class="double">7663</td></tr>
# <tr><td class="char">Minimum Größe der Blätter</td><td class="double">5</td></tr>
# <tr><td class="char">Zufallszahl Seed</td><td class="double">0</td></tr>
# </tbody>
# </table><table class="sas-dataframe">
# <colgroup><col class="char" /><col class="double" /><col class="double" /></colgroup>
# <thead>
# <tr><th colspan="3">Entscheidungsbaum für BIG_ORGANICS_PART</th></tr>
# <th class="char">Analysevariable</th>
# <th class="double">Importance</th>
# <th class="double">Std</th>
# </thead>
# <tbody>
# <tr><td class="char">DemAge</td><td class="double">1162.2748489</td><td class="double">557.56345001</td></tr>
# <tr><td class="char">DemAffl</td><td class="double">795.36428245</td><td class="double">142.50366322</td></tr>
# <tr><td class="char">DemGender</td><td class="double">436.90303707</td><td class="double">79.125914062</td></tr>
# <tr><td class="char">DemCluster</td><td class="double">230.05630346</td><td class="double">11.030213488</td></tr>
# <tr><td class="char">DemTVReg</td><td class="double">15.508180337</td><td class="double">5.7086567195</td></tr>
# <tr><td class="char">PromSpend</td><td class="double">2.4745909561</td><td class="double">3.8173596422</td></tr>
# <tr><td class="char">PromClass</td><td class="double">2.2921999011</td><td class="double">2.472582615</td></tr>
# <tr><td class="char">PromTime</td><td class="double">2.0971117552</td><td class="double">1.1775541751</td></tr>
# <tr><td class="char">DemClusterGroup</td><td class="double">1.2744043341</td><td class="double">0.9677801278</td></tr>
# <tr><td class="char">DemReg</td><td class="double">0.2750754264</td><td class="double">0.4282635132</td></tr>
# </tbody>
# </table><table class="sas-dataframe">
# <colgroup><col class="varchar" /><col class="varchar" /><col class="int64" /><col class="int64" /><col class="object" /></colgroup>
# <thead>
# <tr><th colspan="5">CAS-Tabellen ausgeben</th></tr>
# <th class="varchar">CAS-Bibliothek</th>
# <th class="varchar">Name</th>
# <th class="int64">Anzahl der Zeilen</th>
# <th class="int64">Anzahl der Spalten</th>
# <th class="object">Table</th>
# </thead>
# <tbody>
# <tr><td class="varchar">CASUSER(johndoe)</td><td class="varchar">gb_model</td><td class="int64">628</td><td class="int64">120</td><td class="object">CASTable('gb_model', caslib='CASUSER(johndoe)')</td></tr>
# </tbody>
# </table></div>
# [OutputCasTables]
#
#               casLib        Name    Rows  Columns  \
#  0  CASUSER(johndoe)  _scored_gb  111115        6
#
#                                              casTable
#  0  CASTable('_scored_gb', caslib='CASUSER(johndoe)')
#
# [ScoreInfo]
#
#                                Descr                             Value
#  0  Anzahl eingelesene Beobachtungen                            111115
#  1   Anzahl verwendete Beobachtungen                            111115
#  2    Fehlklassifizierungsfehler (%)                      18,840840571
#
# [ErrorMetricInfo]
#
#     TreeID  Trees  NLeaves       MCR   LogLoss       ASE      RASE     MAXAE
#  0     0.0    1.0     31.0  0.247716  0.533085  0.175997  0.419520  0.772701
#  1     1.0    2.0     63.0  0.247716  0.512896  0.167811  0.409647  0.792989
#  2     2.0    3.0     95.0  0.247716  0.496574  0.161093  0.401363  0.811707
#  3     3.0    4.0    127.0  0.247716  0.483260  0.155610  0.394474  0.828662
#  4     4.0    5.0    159.0  0.227377  0.472346  0.151144  0.388772  0.843178
#  5     5.0    6.0    191.0  0.213608  0.462784  0.147304  0.383802  0.856548
#  6     6.0    7.0    223.0  0.202943  0.454626  0.144122  0.379633  0.868547
#  7     7.0    8.0    255.0  0.196823  0.447929  0.141556  0.376239  0.876292
#  8     8.0    9.0    287.0  0.192098  0.441800  0.139259  0.373174  0.886671
#  9     9.0   10.0    319.0  0.188408  0.436383  0.137318  0.370564  0.896482
#
# + Elapsed: 0.262s, user: 1.22s, mem: 14mb
# NOTE: Character values have been converted to numeric values at the places given by: (Line):(Column).
#       0:35    0:129
# NOTE: Duplicate messages output by DATA step:
# NOTE: Character values have been converted to numeric values at the places given by: (Line):(Column).  (occurred 6 times)
#       0:35    0:129  (occurred 6 times)
# [InputCasTables]
#
#               casLib        Name    Rows  Columns  \
#  0  CASUSER(johndoe)  _scored_gb  111115        6
#
#                                              casTable
#  0  CASTable('_scored_gb', caslib='CASUSER(johndoe)')
#
# [OutputCasTables]
#
#               casLib        Name    Rows  Columns  Append  \
#  0  CASUSER(johndoe)  _scored_gb  111115        8     NaN
#
#                                              casTable
#  0  CASTable('_scored_gb', caslib='CASUSER(johndoe)')
#
# + Elapsed: 0.0275s, user: 0.06s, sys: 0.03s, mem: 6.21mb

# %% [markdown]
# ### Neural Network

# %%
nn = sess.neuralNet.annTrain(
  table={
    "name":"big_organics_part",
    "where":"strip(put(_partind_, best.))='1'"
  },
  validTable={
    "name":"big_organics_part",
    "where":"strip(put(_partind_, best.))='0'"
  },
  inputs=all_inputs,
  nominals=class_vars,
  target="targetbuy",
  hiddens={1},
  acts={"TANH"},
  combs={"LINEAR"},
  targetAct="SOFTMAX",
  errorFunc="ENTROPY",
  std="MIDRANGE",
  randDist="UNIFORM",
  scaleInit=1,
  nloOpts={
    "optmlOpt":{"maxIters":250, "fConv":1e-10}, 
    "lbfgsOpt":{"numCorrections":6},
    "printOpt":{"printLevel":"printDetail"},
    "validate":{"frequency":1}
  },
  casOut={"name":"nnet_model", "replace":True}
)

# Output model statistics
render_html(nn)

# Score 
sess.neuralNet.annScore(
  table={"name":"big_organics_part"},
  modelTable={"name":"nnet_model"},
  casOut={"name":"_scored_nn", "replace":True},
  copyVars={"targetbuy", "_partind_"}
)

# Create p_targetbuy0 and p_targetbuy1 as _nn_predp_ is the probability of event in _nn_predname_
sess.dataStep.runCode(
  code="""data _scored_nn; set _scored_nn; if _nn_predname_=1 then do; p_targetbuy1=_nn_predp_; 
    p_targetbuy0=1-p_targetbuy1; end; if _nn_predname_=0 then do; p_targetbuy0=_nn_predp_; p_targetbuy1=1-p_targetbuy0; end; run;"""
)
# Out:
#     <style type="text/css">
#     div.cas-results {
#         overflow-x: auto;
#     }
#     div.cas-results > * {
#         margin-left: auto !important;
#         margin-right: auto !important;
#     }
#     div.cas-results .sas-dataframe th[colspan],
#     div.cas-results .byline {
#         text-align: center;
#         font-size: 110%;
#     }
#     div.cas-results .sas-dataframe > tbody > tr:nth-child(even) {
#         background-color: #f8f8f8;
#     }
#     div.cas-results .sas-dataframe td,
#     div.cas-results .sas-dataframe th {
#         border: 1px solid #aaaaaa;
#         padding: 5px 10px;
#     }
#     div.cas-results .sas-dataframe th {
#         background-color: #f0f0f0;
#     }
#     div.cas-results .sas-dataframe .double,
#     div.cas-results .sas-dataframe .int32,
#     div.cas-results .sas-dataframe .int64,
#     div.cas-results .sas-dataframe .decsext,
#     div.cas-results .sas-dataframe .decquad {
#         text-align: right;
#     }
#     </style>
# <div class="cas-results"><table class="sas-dataframe">
# <colgroup><col class="double" /><col class="double" /><col class="double" /><col class="double" /><col class="double" /><col class="double" /><col class="double" /><col class="double" /><col class="double" /><col class="double"
#  0  CASUSER(johndoe)  _scored_nn  111115        4
#
#                                              casTable
#  0  CASTable('_scored_nn', caslib='CASUSER(johndoe)')
#
# [OutputCasTables]
#
#               casLib        Name    Rows  Columns  Append  \
#  0  CASUSER(johndoe)  _scored_nn  111115        6     NaN
#
#                                              casTable
#  0  CASTable('_scored_nn', caslib='CASUSER(johndoe)')
#
# + Elapsed: 0.0318s, user: 0.06s, sys: 0.04s, mem: 4.89mb
# NOTE: Character values have been converted to numeric values at the places given by: (Line):(Column).
#       0:35    0:127
# NOTE: Duplicate messages output by DATA step:
# NOTE: Character values have been converted to numeric values at the places given by: (Line):(Column).  (occurred 6 times)
#       0:35    0:127  (occurred 6 times)

# %% [markdown]
# ### Assess Models

# %%
def assess_model(prefix):
    return sess.percentile.assess(
      table={
        "name":"_scored_" + prefix, 
        "where": "strip(put(_partind_, best.))='0'"
      },
      inputs=[{"name":"p_targetbuy1"}],      
      response="targetbuy",
      event="1",
      pVar={"p_targetbuy0"},
      pEvent={"0"}      
    )

rfAssess=assess_model(prefix="rf")    
rf_fitstat =rfAssess.FitStat
rf_rocinfo =rfAssess.ROCInfo
rf_liftinfo=rfAssess.LIFTInfo

gbAssess=assess_model(prefix="gb")    
gb_fitstat =gbAssess.FitStat
gb_rocinfo =gbAssess.ROCInfo
gb_liftinfo=gbAssess.LIFTInfo

nnAssess=assess_model(prefix="nn")    
nn_fitstat =nnAssess.FitStat
nn_rocinfo =nnAssess.ROCInfo
nn_liftinfo=nnAssess.LIFTInfo

nn_rocinfo
# Out:
# ROC-Informationen für _SCORED_NN
#
#         Variable Event  CutOff      TP       FP      FN       TN  Sensitivity  \
# 0   p_targetbuy1     1    0.00  6503.0  18183.0     0.0      0.0     1.000000
# 1   p_targetbuy1     1    0.01  6503.0  18183.0     0.0      0.0     1.000000
# 2   p_targetbuy1     1    0.02  6503.0  18183.0     0.0      0.0     1.000000
# 3   p_targetbuy1     1    0.03  6503.0  17995.0     0.0    188.0     1.000000
# 4   p_targetbuy1     1    0.04  6490.0  17364.0    13.0    819.0     0.998001
# ..           ...   ...     ...     ...      ...     ...      ...          ...
# 95  p_targetbuy1     1    0.95   243.0      5.0  6260.0  18178.0     0.037367
# 96  p_targetbuy1     1    0.96   206.0      1.0  6297.0  18182.0     0.031678
# 97  p_targetbuy1     1    0.97   163.0      1.0  6340.0  18182.0     0.025065
# 98  p_targetbuy1     1    0.98   104.0      0.0  6399.0  18183.0     0.015993
# 99  p_targetbuy1     1    0.99    57.0      0.0  6446.0  18183.0     0.008765
#
#     Specificity   KS  ...    F_HALF       FPR       ACC       FDR        F1  \
# 0      0.000000  0.0  ...  0.308940  1.000000  0.263429  0.736571  0.417006
# 1      0.000000  0.0  ...  0.308940  1.000000  0.263429  0.736571  0.417006
# 2      0.000000  0.0  ...  0.308940  1.000000  0.263429  0.736571  0.417006
# 3      0.010339  0.0  ...  0.311163  0.989661  0.271044  0.734550  0.419535
# 4      0.045042  0.0  ...  0.318390  0.954958  0.296079  0.727928  0.427578
# ..          ...  ...  ...       ...       ...       ...       ...       ...
# 95     0.999725  0.0  ...  0.162108  0.000275  0.746212  0.020161  0.071989
# 96     0.999945  0.0  ...  0.140499  0.000055  0.744876  0.004831  0.061401
# 97     0.999945  0.0  ...  0.113843  0.000055  0.743134  0.006098  0.048898
# 98     1.000000  0.0  ...  0.075155  0.000000  0.740784  0.000000  0.031482
# 99     1.000000  0.0  ...  0.042341  0.000000  0.738880  0.000000  0.017378
#
#            C      Gini     Gamma       Tau  MISCEVENT
# 0   0.800483  0.600965  0.608713  0.233225   0.736571
# 1   0.800483  0.600965  0.608713  0.233225   0.736571
# 2   0.800483  0.600965  0.608713  0.233225   0.736571
# 3   0.800483  0.600965  0.608713  0.233225   0.728956
# 4   0.800483  0.600965  0.608713  0.233225   0.703921
# ..       ...       ...       ...       ...        ...
# 95  0.800483  0.600965  0.608713  0.233225   0.253788
# 96  0.800483  0.600965  0.608713  0.233225   0.255124
# 97  0.800483  0.600965  0.608713  0.233225   0.256866
# 98  0.800483  0.600965  0.608713  0.233225   0.259216
# 99  0.800483  0.600965  0.608713  0.233225   0.261120
#
# [100 rows x 21 columns]

# %% [markdown]
# ### Create ROC and Lift plots (using Validation data)

# %% [markdown]
# #### Prepare assessment results for plotting

# %%
# Add new variable to indicate type of model
rf_liftinfo["model"]="Forest"
rf_rocinfo["model"]="Forest"
gb_liftinfo["model"]="GradientBoosting"
gb_rocinfo["model"]="GradientBoosting"
nn_liftinfo["model"]="NeuralNetwork"
nn_rocinfo["model"]="NeuralNetwork"

# Append data
all_liftinfo=rf_liftinfo.append(gb_liftinfo, ignore_index=True) \
    .append(nn_liftinfo, ignore_index=True)  
all_rocinfo=rf_rocinfo.append(gb_rocinfo, ignore_index=True) \
    .append(nn_rocinfo, ignore_index=True)

# %% [markdown]
# #### Print AUC (Area Under the ROC Curve)

# %%
print("AUC (using validation data)".center(80, '-'))
all_rocinfo[["model", "C"]].drop_duplicates(keep="first").sort_values(by="C", ascending=False)
# Out:
# --------------------------AUC (using validation data)---------------------------
#                 model         C
# 0              Forest  0.868725
# 100  GradientBoosting  0.830403
# 200     NeuralNetwork  0.800483

# %% [markdown]
# #### Draw ROC and Lift plots

# %%
#/* Draw ROC charts */ 
plt.figure()
for key, grp in all_rocinfo.groupby(["model"]):
    plt.plot(grp["FPR"], grp["Sensitivity"], label=key)
plt.plot([0,1], [0,1], "k--")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.grid(True)
plt.legend(loc="best")
plt.title("ROC Curve (using validation data)")
plt.show()

#/* Draw lift charts */
plt.figure()
for key, grp in all_liftinfo.groupby(["model"]):
    plt.plot(grp["Depth"], grp["Lift"], label=key)
plt.xlabel("Depth")
plt.ylabel("Lift")
plt.grid(True)
plt.legend(loc="best")
plt.title("Lift Chart (using validation data)")
plt.show()
# Out:
# Text(0.5, 0, 'False Positive Rate')
# Text(0, 0.5, 'True Positive Rate')
# Text(0.5, 1.0, 'ROC Curve (using validation data)')
# Text(0.5, 0, 'Depth')
# Text(0, 0.5, 'Lift')
# Text(0.5, 1.0, 'Lift Chart (using validation data)')

# %% [markdown]
# ### End CAS session

# %%
sess.close()
