# %%
import sys
import swat

# %%
conn = swat.CAS('centis', 5570, 'sasdemo', 'SASpw123')

# %%
conn.tableinfo(caslib='casuser')
# Out:
# [TableInfo]
#
#        Name    Rows  Columns Encoding         CreateTimeFormatted  \
#  0  CONTROL    5000       59    utf-8  18. Februar 2017 19.53 Uhr
#  1    SYNTH  500557      159    utf-8  18. Februar 2017 19.53 Uhr
#
#               ModTimeFormatted JavaCharSet    CreateTime       ModTime  Global  \
#  0  18. Februar 2017 19.53 Uhr        UTF8  1.803067e+09  1.803067e+09       1
#  1  18. Februar 2017 19.53 Uhr        UTF8  1.803067e+09  1.803067e+09       1
#
#     Repeated  View                SourceName SourceCaslib  Compressed  Creator  \
#  0         0     0  _T_CF288B9B_7F0A464E8BE8                        0  sasdemo
#  1         0     0  _T_CF288C48_7F0A45CE7BE8                        0  sasdemo
#
#    Modifier
#  0
#  1
#
# + Elapsed: 0.000747s, sys: 0.000724s, mem: 0.0744mb

# %% [markdown]
# ## Requires generation of table 'SYNTH' in CAS (see project Syn_Data_Example)

# %%
tab=conn.CASTable('SYNTH')
tab.columninfo()
# Out:
# [ColumnInfo]
#
#        Column   ID    Type  RawLength  FormattedLength Format  NFL  NFD
#  0      parm1    1  double          8               12           0    0
#  1      parm2    2  double          8               12           0    0
#  2      parm3    3  double          8               12           0    0
#  3      parm4    4  double          8               12           0    0
#  4      parm5    5  double          8               12           0    0
#  5      parm6    6  double          8               12           0    0
#  6      parm7    7  double          8               12           0    0
#  7      parm8    8  double          8               12           0    0
#  8      parm9    9  double          8               12           0    0
#  9     parm10   10  double          8               12           0    0
#  10    parm11   11  double          8               12           0    0
#  11    parm12   12  double          8               12           0    0
# ...

# %%
conn.summary(tab)
# Out:
# [Summary]
#
#  Beschreibende Statistiken für SYNTH
#
#        Column           Min            Max         N  NMiss          Mean  \
#  0      parm1  7.927005e-02       0.079270  500557.0    0.0      0.079270
#  1      parm2  3.224181e-01       0.322418  500557.0    0.0      0.322418
#  2      parm3  2.453772e-01       0.245377  500557.0    0.0      0.245377
#  3      parm4 -1.658324e-01      -0.165832  500557.0    0.0     -0.165832
#  4      parm5  4.620435e-01       0.462043  500557.0    0.0      0.462043
#  5      parm6 -3.701466e-01      -0.370147  500557.0    0.0     -0.370147
#  6      parm7 -4.246062e-02      -0.042461  500557.0    0.0     -0.042461
#  7      parm8  3.126011e-01       0.312601  500557.0    0.0      0.312601
#  8      parm9  1.971967e-02       0.019720  500557.0    0.0      0.019720
#  9     parm10  3.675777e-01       0.367578  500557.0    0.0      0.367578
#  10    parm11 -4.449124e-02      -0.044491  500557.0    0.0     -0.044491
# ...
